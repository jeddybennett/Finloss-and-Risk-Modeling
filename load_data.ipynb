# %%
import pandas as pd
import os
from IPython.display import display, Markdown

# %%
data_dir = 'data/'

affected_count_range_df = pd.read_csv(os.path.join(data_dir, 'affected_count_range.csv'))
count_by_company_size_and_type_df = pd.read_csv(os.path.join(data_dir, 'count_by_company_size_and_type.csv'))
cyber_case_count_by_type_df = pd.read_csv(os.path.join(data_dir, 'cyber_case_count_by_type.csv'))
data_breach_count_by_country_df = pd.read_csv(os.path.join(data_dir, 'data_breach_count_by_country.csv'))
data_breach_count_by_state_df = pd.read_csv(os.path.join(data_dir, 'data_breach_count_by_state.csv'))
economic_loss_df = pd.read_csv(os.path.join(data_dir, 'economic_loss.csv'))
financial_services_historical_case_count_df = pd.read_csv(os.path.join(data_dir, 'financial_services_historical_case_count.csv'))
fines_penalties_df = pd.read_csv(os.path.join(data_dir, 'fines_penalties.csv'))
litigated_cases_df = pd.read_csv(os.path.join(data_dir, 'litigated_cases.csv'))
response_costs_df = pd.read_csv(os.path.join(data_dir, 'response_costs.csv'))

# %%
display(Markdown("### Affected Count Range"))
display(affected_count_range_df)
# Out:
# ### Affected Count Range
#   Affected Count Range  Case Count  Average Affected Count
# 0              (0, 10]       58269                     5.0
# 1            (10, 100]       14872                    55.0
# 2            (100, 1K]       20437                   550.0
# 3            (1K, 10K]       14143                  5500.0
# 4          (10K, 100K]        6651                 55000.0
# 5           (100K, 1M]        2660                550000.0
# 6               (1M, )        1726               1500000.0
# 7                Total      118758                     NaN

# %%
display(Markdown("### Count by Company Size and Type"))
display(count_by_company_size_and_type_df)
# Out:
# ### Count by Company Size and Type
#   Company Size    PRV    PUB   GOV    NPR  Total
# 0        Small  15902    485   307  710.0  17404
# 1       Medium  19387   1436   675  620.0  22118
# 2        Large  22430   2490  2428  953.0  28301
# 3   Very Large  12727   4717  1498  435.0  19377
# 4        Giant   7663   7206  1819  550.0  17238
# 5         Mega   1666  10306  7842   33.0  19847
# 6     Colossal   1283   3667  2067    NaN   7017
# 7      Unknown  15890   6664  3020  552.0  26126

# %%
display(Markdown("### Cyber Case Count by Type"))
display(cyber_case_count_by_type_df)
# Out:
# ### Cyber Case Count by Type
#                             Affected Count Range  With Affected Count  \
# 0               Industrial Controls & Operations                   25
# 1                             Undetermined/Other                  382
# 2                         IT - Processing Errors                  556
# 3       Identity - Fraudulent Use/Account Access                  736
# 4       IT - Configuration/Implementation Errors                  750
# 5                   Skimming, Physical Tampering                  680
# 6         Privacy - Unauthorized Data Collection                 1125
# 7         Phishing, Spoofing, Social Engineering                 3745
# 8                     Network/Website Disruption                 1031
# 9               Data - Physically Lost or Stolen                 8407
# 10               Data - Unintentional Disclosure                18260
# 11  Privacy - Unauthorized Contact or Disclosure                37719
# ...

# %%
display(Markdown("### Data Breach Count by Country"))
display(data_breach_count_by_country_df)
# Out:
# ### Data Breach Count by Country
#    Country  Case Count
# 0      USA      118810
# 1      CAN       13799
# 2      GBR        4572
# 3      IND        1321
# 4      AUS        1212
# 5      DEU        1092
# 6      FRA        1036
# 7      ITA         820
# 8      BRA         727
# 9      IDN         608
# 10  Others       13431

# %%
display(Markdown("### Data Breach Count by State"))
display(data_breach_count_by_state_df)
# Out:
# ### Data Breach Count by State
#      State  Case Count
# 0       CA       15992
# 1       NY       12561
# 2       TX        7819
# 3       MA        7648
# 4       FL        7302
# 5       IL        6061
# 6       PA        4889
# 7       VA        3631
# 8       GA        3475
# 9       NJ        3338
# 10  Others       46094

# %%
display(Markdown("### Economic Loss"))
display(economic_loss_df)
# Out:
# ### Economic Loss
#                                        Case Type  Case Count (Economic Loss)  \
# 0                        Data - Malicious Breach                         667
# 1   Privacy - Unauthorized Contact or Disclosure                           5
# 2               Data - Physically Lost or Stolen                          41
# 3                Data - Unintentional Disclosure                           9
# 4                     Network/Website Disruption                         215
# 5       Identity - Fraudulent Use/Account Access                         989
# 6         Privacy - Unauthorized Data Collection                           3
# 7         Phishing, Spoofing, Social Engineering                         278
# 8                   Skimming, Physical Tampering                          98
# 9                         IT - Processing Errors                          33
# 10                               Cyber Extortion                        8675
# ...

# %%
display(Markdown("### Financial Services Historical Case Count"))
display(financial_services_historical_case_count_df)
# Out:
# ### Financial Services Historical Case Count
#                               Industry  Prior 2008  2008  2009  2010  2011  \
# 0  Finance, Insurance, And Real Estate        1720  1542   944  1075  1431
#
#    2012  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 0  2013  2578  2514  2798  3144  2685  2778  2249  2236  2139  1637   359

# %%
display(Markdown("### Fines and Penalties"))
display(fines_penalties_df)
# Out:
# ### Fines and Penalties
#                                        Case Type  \
# 0                        Data - Malicious Breach
# 1   Privacy - Unauthorized Contact or Disclosure
# 2               Data - Physically Lost or Stolen
# 3                Data - Unintentional Disclosure
# 4                     Network/Website Disruption
# 5       Identity - Fraudulent Use/Account Access
# 6         Privacy - Unauthorized Data Collection
# 7         Phishing, Spoofing, Social Engineering
# 8                   Skimming, Physical Tampering
# 9                         IT - Processing Errors
# 10                               Cyber Extortion
# 11      IT - Configuration/Implementation Errors
# 12              Industrial Controls & Operations
# 13                                         Total
#
#     Case Count (Fines & Penalties)  Loss Amount (Fines & Penalties)
# 0                              543                        2674547.0
# ...

# %%
display(Markdown("### Litigated Cases"))
display(litigated_cases_df)
# Out:
# ### Litigated Cases
#                                        Case Type  \
# 0                        Data - Malicious Breach
# 1   Privacy - Unauthorized Contact or Disclosure
# 2               Data - Physically Lost or Stolen
# 3                Data - Unintentional Disclosure
# 4                     Network/Website Disruption
# 5       Identity - Fraudulent Use/Account Access
# 6         Privacy - Unauthorized Data Collection
# 7         Phishing, Spoofing, Social Engineering
# 8                   Skimming, Physical Tampering
# 9                         IT - Processing Errors
# 10                               Cyber Extortion
# 11      IT - Configuration/Implementation Errors
# 12              Industrial Controls & Operations
# 13                                         Total
#
#     Case Count (Litigated Cases)  Loss Amount (Litigated Cases)
# 0                          398.0                      5029375.0
# 1                         2590.0                      7572005.0
# ...

# %%
display(Markdown("### Response Costs"))
display(response_costs_df)
# Out:
# ### Response Costs
#                                        Case Type  Case Count (Response Costs)  \
# 0                        Data - Malicious Breach                        206.0
# 1   Privacy - Unauthorized Contact or Disclosure                          1.0
# 2               Data - Physically Lost or Stolen                         15.0
# 3                Data - Unintentional Disclosure                         13.0
# 4                     Network/Website Disruption                        114.0
# 5       Identity - Fraudulent Use/Account Access                          1.0
# 6         Privacy - Unauthorized Data Collection                          NaN
# 7         Phishing, Spoofing, Social Engineering                         21.0
# 8                   Skimming, Physical Tampering                          6.0
# 9                         IT - Processing Errors                          7.0
# 10                               Cyber Extortion                          1.0
# ...
